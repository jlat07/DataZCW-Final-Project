# %%
import csv
import pandas as pd



df = pd.read_csv('/Users/jthompson/dev/DataZCW-Final-Project/Dashboard/date_tweets_locations_50.csv', index_col=0)

# %%
df.dtypes
# Out:
# date                     object
# tweet                    object
# location                 object
# location_abbreviation    object
# sentiment                object
# dtype: object

# %%
df
# Out:
#         date                                              tweet  \
# 0   2020-5-9  Yikes! #COVID19 effect on unemployment figures...
# 1   2020-5-9  One of the most common questions that we are g...
# 2   2020-5-9  RT @BvilleDailyNews: Missourians made nearly 5...
# 3   2020-5-9  Missourians made nearly 55,000 new unemploymen...
# 4   2020-5-9  Missourians made nearly 55,000 new unemploymen...
# 5   2020-5-9  Yikes! #COVID19 effect on unemployment figures...
# 6   2020-5-9  One of the most common questions that we are g...
# 7   2020-5-9  RT @BvilleDailyNews: Missourians made nearly 5...
# 8   2020-5-9  Missourians made nearly 55,000 new unemploymen...
# 9   2020-5-9  Missourians made nearly 55,000 new unemploymen...
# 10  2020-5-9  @MollyJongFast We’ll consider her a #COVID19va...
# 11  2020-5-9  RT @aspiesmom: You choose: risk #Coronavirus O...
# 12  2020-5-9  ICMR teams up with Bharat Biotech to develop i...
# 13  2020-5-9  @LadyRedWave People refusing the #COVID19vacci...
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date                     datetime64[ns]
# tweet                            object
# location                         object
# location_abbreviation            object
# sentiment                        object
# dtype: object

# %%
# dfnew = df.rename(columns={0:'date', 1:'misc', 2:'tweet', 3:'date2', 4:'misc2', 5:'misc2', 6:'misc2', 7:'location', 8:'misc2'})

# %%
# Drop columns
df = df.drop(columns=[1, 3, 4, 5, 6, 8])

# %%
dfnew = df.rename(columns={0:'date', 2:'tweet', 7:'location'})

# %%
dfnew.dtypes
# Out:
# date        object
# tweet       object
# location    object
# dtype: object

# %%
dfnew['date'] = dfnew['date'].str[0:10]

# %%
dfnew
# Out:
#            date                                              tweet  \
# 0    2020-05-09  Yikes! #COVID19 effect on unemployment figures...
# 1    2020-05-09  One of the most common questions that we are g...
# 2    2020-05-09  RT @BvilleDailyNews: Missourians made nearly 5...
# 3    2020-05-09  Missourians made nearly 55,000 new unemploymen...
# 4    2020-05-09  Missourians made nearly 55,000 new unemploymen...
# ..          ...                                                ...
# 926  2020-05-09  RT @ankkinegi: Always keep the faith... 🙏\nIf ...
# 927  2020-05-09  RT @OxfordECentre: In the worldwide race for a...
# 928  2020-05-09  In the worldwide race for a vaccine to stop th...
# 929  2020-05-09  RT @momimlevitating: Bill Gates and his slimeb...
# 930  2020-05-09  #COVID19Vaccine in 8 months... WHAT??? https:/...
#
#                                        location
# 0                            Brooklyn, New York
# 1                                  New York, NY
# ...

# %%
# dfnew['date'].astype(int)
# This can not be applied at the time the data is read in
# dfnew['date'] = pd.to_datetime(dfnew[['Month', 'Day', 'Year']])
dfnew['date'] = pd.to_datetime(dfnew['date'])

# %%
dfnew.dtypes
# Out:
# date        datetime64[ns]
# tweet               object
# location            object
# dtype: object

# %%
#dtypes are already objects(str), but in case they weren't, this would be a fail safe
dfnew['tweet'] = dfnew['tweet'].astype('str')
dfnew['location'] = dfnew['location'].astype('str')

# %%
dfnew.dtypes
# Out:
# date        datetime64[ns]
# tweet               object
# location            object
# dtype: object

# %%
dfnew
# Out:
#           date                                              tweet  \
# 0   2020-05-09  Yikes! #COVID19 effect on unemployment figures...
# 1   2020-05-09  One of the most common questions that we are g...
# 2   2020-05-09  RT @BvilleDailyNews: Missourians made nearly 5...
# 3   2020-05-09  Missourians made nearly 55,000 new unemploymen...
# 4   2020-05-09  Missourians made nearly 55,000 new unemploymen...
# ..         ...                                                ...
# 926 2020-05-09  RT @ankkinegi: Always keep the faith... 🙏\nIf ...
# 927 2020-05-09  RT @OxfordECentre: In the worldwide race for a...
# 928 2020-05-09  In the worldwide race for a vaccine to stop th...
# 929 2020-05-09  RT @momimlevitating: Bill Gates and his slimeb...
# 930 2020-05-09  #COVID19Vaccine in 8 months... WHAT??? https:/...
#
#                                        location
# 0                            Brooklyn, New York
# 1                                  New York, NY
# ...

# %%
states = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AS': 'American Samoa',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'GU': 'Guam',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MP': 'Northern Mariana Islands',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NA': 'National',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'PR': 'Puerto Rico',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VI': 'Virgin Islands',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming'
}

# %%
dfnew[pd.DataFrame(dfnew.location.tolist()).isin(states).any(1)]
# Out:
# Empty DataFrame
# Columns: [date, tweet, location]
# Index: []

# %%
filter = dfnew.location.apply(lambda x: any(item for item in states if item in x))
dfstatesonly = dfnew[filter]

# %%
dfstatesonly
# Out:
#           date                                              tweet  \
# 1   2020-05-09  One of the most common questions that we are g...
# 6   2020-05-09  One of the most common questions that we are g...
# 10  2020-05-09  @MollyJongFast We’ll consider her a #COVID19va...
# 11  2020-05-09  RT @aspiesmom: You choose: risk #Coronavirus O...
# 15  2020-05-09  "#Polio spread fastest in warm months. Each Ju...
# ..         ...                                                ...
# 863 2020-05-09  RT @SuerieMoon: Indeed, these are critical que...
# 885 2020-05-09  Napa company begins testing a potential COVID-...
# 893 2020-05-09  Extraordinary cooperation and accommodations a...
# 913 2020-05-09  #WhistleblowerComplaint set to lift lid on Tru...
# 925 2020-05-09  I think #Trumps campaign is trying to screw th...
#
#                         location
# 1                   New York, NY
# 6                   New York, NY
# 10         Shenandoah Valley, VA
# 11   Pinterest #CDCwhistleblower
# ...

# %%
dfnew
# Out:
#           date                                              tweet  \
# 0   2020-05-09  Yikes! #COVID19 effect on unemployment figures...
# 1   2020-05-09  One of the most common questions that we are g...
# 2   2020-05-09  RT @BvilleDailyNews: Missourians made nearly 5...
# 3   2020-05-09  Missourians made nearly 55,000 new unemploymen...
# 4   2020-05-09  Missourians made nearly 55,000 new unemploymen...
# ..         ...                                                ...
# 926 2020-05-09  RT @ankkinegi: Always keep the faith... 🙏\nIf ...
# 927 2020-05-09  RT @OxfordECentre: In the worldwide race for a...
# 928 2020-05-09  In the worldwide race for a vaccine to stop th...
# 929 2020-05-09  RT @momimlevitating: Bill Gates and his slimeb...
# 930 2020-05-09  #COVID19Vaccine in 8 months... WHAT??? https:/...
#
#                                        location
# 0                            Brooklyn, New York
# 1                                  New York, NY
# ...

# %%
dfnew.to_csv('date_tweets_locations.csv')
